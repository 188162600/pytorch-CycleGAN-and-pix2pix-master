# %% [markdown]
# <a href="https://colab.research.google.com/github/bkkaggle/pytorch-CycleGAN-and-pix2pix/blob/master/CycleGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Take a look at the [repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix) for more information

# %% [markdown]
# # Install

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix

# %%
import os
os.chdir('pytorch-CycleGAN-and-pix2pix/')

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # Datasets
#
# Download one of the official datasets with:
#
# -   `bash ./datasets/download_cyclegan_dataset.sh [apple2orange, summer2winter_yosemite, horse2zebra, monet2photo, cezanne2photo, ukiyoe2photo, vangogh2photo, maps, cityscapes, facades, iphone2dslr_flower, ae_photos]`
#
# Or use your own dataset by creating the appropriate folders and adding in the images.
#
# -   Create a dataset folder under `/dataset` for your dataset.
# -   Create subfolders `testA`, `testB`, `trainA`, and `trainB` under your dataset's folder. Place any images you want to transform from a to b (cat2dog) in the `testA` folder, images you want to transform from b to a (dog2cat) in the `testB` folder, and do the same for the `trainA` and `trainB` folders.

# %%
# !bash ./datasets/download_cyclegan_dataset.sh horse2zebra

# %% [markdown]
# # Pretrained models
#
# Download one of the official pretrained models with:
#
# -   `bash ./scripts/download_cyclegan_model.sh [apple2orange, orange2apple, summer2winter_yosemite, winter2summer_yosemite, horse2zebra, zebra2horse, monet2photo, style_monet, style_cezanne, style_ukiyoe, style_vangogh, sat2map, map2sat, cityscapes_photo2label, cityscapes_label2photo, facades_photo2label, facades_label2photo, iphone2dslr_flower]`
#
# Or add your own pretrained model to `./checkpoints/{NAME}_pretrained/latest_net_G.pt`

# %%
# !bash ./scripts/download_cyclegan_model.sh horse2zebra

# %% [markdown]
# # Training
#
# -   `python train.py --dataroot ./datasets/horse2zebra --name horse2zebra --model cycle_gan`
#
# Change the `--dataroot` and `--name` to your own dataset's path and model's name. Use `--gpu_ids 0,1,..` to train on multiple GPUs and `--batch_size` to change the batch size. I've found that a batch size of 16 fits onto 4 V100s and can finish training an epoch in ~90s.
#
# Once your model has trained, copy over the last checkpoint to a format that the testing model can automatically detect:
#
# Use `cp ./checkpoints/horse2zebra/latest_net_G_A.pth ./checkpoints/horse2zebra/latest_net_G.pth` if you want to transform images from class A to class B and `cp ./checkpoints/horse2zebra/latest_net_G_B.pth ./checkpoints/horse2zebra/latest_net_G.pth` if you want to transform images from class B to class A.

# %%
# !python train.py --dataroot ./datasets/monet2photo --name monet2photo --model cycle_gan --display_id -1
# Out:
# ^C
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/monet2photo        	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: -1                            	[default: 1]
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#            encoder_max_nc: 128
#            encoder_min_nc: 64
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                  lambda_A: 10.0
#                  lambda_B: 10.0
#           lambda_identity: 0.5
#                 load_iter: 0                             	[default: 0]
#                 load_size: 286
#                        lr: 0.0002
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: inf
#       max_encode_features: 10000
#                     model: cycle_gan
#                  n_epochs: 100
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: monet2photo                   	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: resnet_9blocks
#                       ngf: 64
#                no_dropout: True
#                   no_flip: False
#                   no_html: False
#                      norm: instance
#    num_options_each_layer: 8                             	[default: 8]
#                num_shared: 4
#               num_threads: 4
#                 output_nc: 3
#                     phase: train
#                 pool_size: 50
#                preprocess: resize_and_crop
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                    suffix:
#          update_html_freq: 1000
#                 use_wandb: False
#                   verbose: False
#        wandb_project_name: CycleGAN-and-pix2pix
# ----------------- End -------------------
# NVIDIA GeForce RTX 3060 Laptop GPU
# dataset [UnalignedDataset] was created
# The number of training images = 6287
# gpu_ids [0]
# initialize network with normal
# gpu_ids [0]
# initialize network with normal
# gpu_ids [0]
# initialize network with normal
# torch.Size([1, 128, 64, 64]) 524288 10000
# torch.Size([1, 128, 32, 32]) 131072 10000
# torch.Size([1, 128, 16, 16]) 32768 10000
# torch.Size([1, 128, 8, 8]) 8192 10000
# dummy 196608
# self.features.shape torch.Size([1, 64, 256, 256])
# self.features.shape torch.Size([1, 128, 128, 128])
# self.features.shape torch.Size([1, 256, 64, 64])
# dummy 196608
# self.features.shape torch.Size([1, 64, 256, 256])
# self.features.shape torch.Size([1, 128, 128, 128])
# self.features.shape torch.Size([1, 256, 64, 64])
# torch.Size([1, 256, 32, 32]) 262144 10000
# torch.Size([1, 256, 16, 16]) 65536 10000
# torch.Size([1, 256, 8, 8]) 16384 10000
# torch.Size([1, 256, 4, 4]) 4096 10000
# dummy 1048576
# dummy 1048576
# torch.Size([1, 256, 32, 32]) 262144 10000
# torch.Size([1, 256, 16, 16]) 65536 10000
# torch.Size([1, 256, 8, 8]) 16384 10000
# torch.Size([1, 256, 4, 4]) 4096 10000
# dummy 1048576
# self.features.shape torch.Size([1, 3, 256, 256])
# dummy 1048576
# self.features.shape torch.Size([1, 3, 256, 256])
# initialize network with normal
# initialize network with normal
# model [CycleGANModel] was created
# shared [None, None, None, None, None, None, None, None, None, None] 0
# shared [None, None, None, None, None, None, None, None, None, None] 1
# shared [None, None, None, None, None, None, None, None, None, None] 2
# shared [None, None, None, None, None, None, None, None, None, None] 3
# shared [None, None, None, None, None, None, None, None, None, None] 4
# shared [None, None, None, None, None, None, None, None, None, None] 5
# shared [None, None, None, None, None, None, None, None, None, None] 6
# shared [None, None, None, None, None, None, None, None, None, None] 7
# shared [None, None, None, None, None, None, None, None, None, None] 8
# shared [None, None, None, None, None, None, None, None, None, None] 9
# encoder Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (1): ReLU()
#   (2): Conv2d(64, 128, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (3): ReLU()
#   (4): Conv2d(128, 128, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (5): ReLU()
#   (6): Conv2d(128, 128, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (7): ReLU()
#   (8): Conv2d(128, 128, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (9): ReLU()
# )
# dummy_input torch.Size([1, 3, 256, 256])
# device cuda:0
# shared [None, 0, 0, 0, 0, 0, 0, 0] 0
# shared [None, 0, 0, 0, 0, 0, 0, 0] 1
# shared [None, 0, 0, 0, 0, 0, 0, 0] 2
# shared [None, 0, 0, 0, 0, 0, 0, 0] 3
# shared [None, 0, 0, 0, 0, 0, 0, 0] 4
# shared [None, 0, 0, 0, 0, 0, 0, 0] 5
# shared [None, 0, 0, 0, 0, 0, 0, 0] 6
# shared [None, 0, 0, 0, 0, 0, 0, 0] 7
# encoder Sequential(
#   (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (1): ReLU()
#   (2): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (3): ReLU()
#   (4): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (5): ReLU()
#   (6): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (7): ReLU()
# )
# dummy_input torch.Size([1, 256, 64, 64])
# device cuda:0
# shared [None, None, None, None, None, None, None, None, None] 0
# shared [None, None, None, None, None, None, None, None, None] 1
# shared [None, None, None, None, None, None, None, None, None] 2
# shared [None, None, None, None, None, None, None, None, None] 3
# shared [None, None, None, None, None, None, None, None, None] 4
# shared [None, None, None, None, None, None, None, None, None] 5
# shared [None, None, None, None, None, None, None, None, None] 6
# shared [None, None, None, None, None, None, None, None, None] 7
# shared [None, None, None, None, None, None, None, None, None] 8
# encoder Sequential(
#   (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (1): ReLU()
#   (2): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (3): ReLU()
#   (4): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (5): ReLU()
#   (6): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (7): ReLU()
# )
# dummy_input torch.Size([1, 256, 64, 64])
# device cuda:0
# device cuda:0
# device cuda:0
# device cuda:0
# section Section(
#   (step_classifier_encoder): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU()
#     (2): Conv2d(64, 128, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (3): ReLU()
#     (4): Conv2d(128, 128, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (5): ReLU()
#     (6): Conv2d(128, 128, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (7): ReLU()
#     (8): Conv2d(128, 128, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (9): ReLU()
#   )
#   (0,0): ReflectionPad2d((3, 3, 3, 3))
#   (0,1): ReflectionPad2d((3, 3, 3, 3))
#   (0,2): ReflectionPad2d((3, 3, 3, 3))
#   (0,3): ReflectionPad2d((3, 3, 3, 3))
#   (0,4): ReflectionPad2d((3, 3, 3, 3))
#   (0,5): ReflectionPad2d((3, 3, 3, 3))
#   (0,6): ReflectionPad2d((3, 3, 3, 3))
#   (0,7): ReflectionPad2d((3, 3, 3, 3))
#   (1,0): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1))
#   (1,1): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1))
#   (1,2): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1))
#   (1,3): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1))
#   (1,4): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1))
#   (1,5): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1))
#   (1,6): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1))
#   (1,7): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1))
#   (2,0): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (2,1): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (2,2): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (2,3): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (2,4): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (2,5): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (2,6): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (2,7): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (3,0): ReLU(inplace=True)
#   (3,1): ReLU(inplace=True)
#   (3,2): ReLU(inplace=True)
#   (3,3): ReLU(inplace=True)
#   (3,4): ReLU(inplace=True)
#   (3,5): ReLU(inplace=True)
#   (3,6): ReLU(inplace=True)
#   (3,7): ReLU(inplace=True)
#   (4,0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (4,1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (4,2): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (4,3): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (4,4): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (4,5): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (4,6): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (4,7): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (5,0): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (5,1): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (5,2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (5,3): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (5,4): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (5,5): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (5,6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (5,7): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (6,0): ReLU(inplace=True)
#   (6,1): ReLU(inplace=True)
#   (6,2): ReLU(inplace=True)
#   (6,3): ReLU(inplace=True)
#   (6,4): ReLU(inplace=True)
#   (6,5): ReLU(inplace=True)
#   (6,6): ReLU(inplace=True)
#   (6,7): ReLU(inplace=True)
#   (7,0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (7,1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (7,2): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (7,3): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (7,4): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (7,5): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (7,6): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (7,7): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (8,0): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (8,1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (8,2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (8,3): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (8,4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (8,5): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (8,6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (8,7): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (9,0): ReLU(inplace=True)
#   (9,1): ReLU(inplace=True)
#   (9,2): ReLU(inplace=True)
#   (9,3): ReLU(inplace=True)
#   (9,4): ReLU(inplace=True)
#   (9,5): ReLU(inplace=True)
#   (9,6): ReLU(inplace=True)
#   (9,7): ReLU(inplace=True)
#   (classifier): NextStepClassifier(
#     (encoder): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#       (1): ReLU()
#       (2): Conv2d(64, 128, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#       (3): ReLU()
#       (4): Conv2d(128, 128, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#       (5): ReLU()
#       (6): Conv2d(128, 128, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#       (7): ReLU()
#       (8): Conv2d(128, 128, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#       (9): ReLU()
#     )
#     (nets): ModuleList(
#       (0-9): 10 x LSTMCell(8192, 80)
#     )
#   )
# )
# section Section(
#   (step_classifier_encoder): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU()
#     (2): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (3): ReLU()
#     (4): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (5): ReLU()
#     (6): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (7): ReLU()
#   )
#   (0,0): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (0,1): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (0,2): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (0,3): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (0,4): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (0,5): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (0,6): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (0,7): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (1,0): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (1,1): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (1,2): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (1,3): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (2,0): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (2,1): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (2,2): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (2,3): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (3,0): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (3,1): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (3,2): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (3,3): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (4,0): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (4,1): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (4,2): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (4,3): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (5,0): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (5,1): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (5,2): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (5,3): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (6,0): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (6,1): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (6,2): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (6,3): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (7,0): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (7,1): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (7,2): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (7,3): ResnetBlock(
#     (conv_block): Sequential(
#       (0): ReflectionPad2d((1, 1, 1, 1))
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (3): ReLU(inplace=True)
#       (4): ReflectionPad2d((1, 1, 1, 1))
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#       (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     )
#   )
#   (classifier): NextStepClassifier(
#     (encoder): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#       (1): ReLU()
#       (2): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#       (3): ReLU()
#       (4): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#       (5): ReLU()
#       (6): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#       (7): ReLU()
#     )
#     (nets): ModuleList(
#       (0-7): 8 x LSTMCell(4096, 64)
#     )
#   )
# )
# section Section(
#   (step_classifier_encoder): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU()
#     (2): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (3): ReLU()
#     (4): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (5): ReLU()
#     (6): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (7): ReLU()
#   )
#   (0,0): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (0,1): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (0,2): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (0,3): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (0,4): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (0,5): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (0,6): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (0,7): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (1,0): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (1,1): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (1,2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (1,3): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (1,4): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (1,5): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (1,6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (1,7): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (2,0): ReLU(inplace=True)
#   (2,1): ReLU(inplace=True)
#   (2,2): ReLU(inplace=True)
#   (2,3): ReLU(inplace=True)
#   (2,4): ReLU(inplace=True)
#   (2,5): ReLU(inplace=True)
#   (2,6): ReLU(inplace=True)
#   (2,7): ReLU(inplace=True)
#   (3,0): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (3,1): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (3,2): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (3,3): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (3,4): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (3,5): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (3,6): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (3,7): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (4,0): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (4,1): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (4,2): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (4,3): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (4,4): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (4,5): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (4,6): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (4,7): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (5,0): ReLU(inplace=True)
#   (5,1): ReLU(inplace=True)
#   (5,2): ReLU(inplace=True)
#   (5,3): ReLU(inplace=True)
#   (5,4): ReLU(inplace=True)
#   (5,5): ReLU(inplace=True)
#   (5,6): ReLU(inplace=True)
#   (5,7): ReLU(inplace=True)
#   (6,0): ReflectionPad2d((3, 3, 3, 3))
#   (6,1): ReflectionPad2d((3, 3, 3, 3))
#   (6,2): ReflectionPad2d((3, 3, 3, 3))
#   (6,3): ReflectionPad2d((3, 3, 3, 3))
#   (6,4): ReflectionPad2d((3, 3, 3, 3))
#   (6,5): ReflectionPad2d((3, 3, 3, 3))
#   (6,6): ReflectionPad2d((3, 3, 3, 3))
#   (6,7): ReflectionPad2d((3, 3, 3, 3))
#   (7,0): Conv2d(64, 3, kernel_size=(7, 7), stride=(1, 1))
#   (7,1): Conv2d(64, 3, kernel_size=(7, 7), stride=(1, 1))
#   (7,2): Conv2d(64, 3, kernel_size=(7, 7), stride=(1, 1))
#   (7,3): Conv2d(64, 3, kernel_size=(7, 7), stride=(1, 1))
#   (7,4): Conv2d(64, 3, kernel_size=(7, 7), stride=(1, 1))
#   (7,5): Conv2d(64, 3, kernel_size=(7, 7), stride=(1, 1))
#   (7,6): Conv2d(64, 3, kernel_size=(7, 7), stride=(1, 1))
#   (7,7): Conv2d(64, 3, kernel_size=(7, 7), stride=(1, 1))
#   (8,0): Tanh()
#   (8,1): Tanh()
#   (8,2): Tanh()
#   (8,3): Tanh()
#   (8,4): Tanh()
#   (8,5): Tanh()
#   (8,6): Tanh()
#   (8,7): Tanh()
#   (classifier): NextStepClassifier(
#     (encoder): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#       (1): ReLU()
#       (2): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#       (3): ReLU()
#       (4): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#       (5): ReLU()
#       (6): Conv2d(256, 256, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#       
# (epoch: 3, iters: 4926, time: 0.619, data: 0.000) D_A: 0.347 G_A: 0.277 cycle_A: 1.679 idt_A: 1.283 D_B: 0.029 G_B: 0.074 cycle_B: 2.806 idt_B: 0.791
# (epoch: 3, iters: 5026, time: 0.597, data: 0.001) D_A: 0.115 G_A: 0.488 cycle_A: 1.348 idt_A: 1.345 D_B: 0.320 G_B: 0.622 cycle_B: 3.541 idt_B: 0.879
# (epoch: 3, iters: 5126, time: 0.588, data: 0.000) D_A: 0.188 G_A: 0.756 cycle_A: 3.739 idt_A: 0.804 D_B: 0.061 G_B: 0.215 cycle_B: 1.623 idt_B: 2.035
# (epoch: 3, iters: 5226, time: 0.588, data: 0.000) D_A: 0.028 G_A: 1.205 cycle_A: 2.510 idt_A: 1.719 D_B: 0.056 G_B: 0.528 cycle_B: 3.317 idt_B: 1.160
# c:\Users\18816\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\lr_scheduler.py:139: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Traceback (most recent call last):
#   File "c:\pytorch-CycleGAN-and-pix2pix-master\train.py", line 45, in <module>
#     for i, data in enumerate(dataset):  # inner loop within one epoch
#   File "c:\pytorch-CycleGAN-and-pix2pix-master\data\__init__.py", line 90, in __iter__
#     for i, data in enumerate(self.dataloader):
#   File "c:\Users\18816\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py", line 633, in __next__
#     data = self._next_data()
#   File "c:\Users\18816\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py", line 1345, in _next_data
#     return self._process_data(data)
#   File "c:\Users\18816\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py", line 1371, in _process_data
#     data.reraise()
#   File "c:\Users\18816\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_utils.py", line 644, in reraise
#     raise exception
# FileNotFoundError: Caught FileNotFoundError in DataLoader worker process 2.
# Original Traceback (most recent call last):
#   File "c:\Users\18816\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\_utils\worker.py", line 308, in _worker_loop
#     data = fetcher.fetch(index)
#   File "c:\Users\18816\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\_utils\fetch.py", line 51, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "c:\Users\18816\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\_utils\fetch.py", line 51, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "c:\pytorch-CycleGAN-and-pix2pix-master\data\unaligned_dataset.py", line 57, in __getitem__
#     A_img = Image.open(A_path).convert('RGB')
#   File "c:\Users\18816\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py", line 3236, in open
#     fp = builtins.open(filename, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: './datasets/monet2photo\\trainA\\01092.jpg'

# %% [markdown]
# # Testing
#
# -   `python test.py --dataroot datasets/horse2zebra/testA --name horse2zebra_pretrained --model test --no_dropout`
#
# Change the `--dataroot` and `--name` to be consistent with your trained model's configuration.
#
# > from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix:
# > The option --model test is used for generating results of CycleGAN only for one side. This option will automatically set --dataset_mode single, which only loads the images from one set. On the contrary, using --model cycle_gan requires loading and generating results in both directions, which is sometimes unnecessary. The results will be saved at ./results/. Use --results_dir {directory_path_to_save_result} to specify the results directory.
#
# > For your own experiments, you might want to specify --netG, --norm, --no_dropout to match the generator architecture of the trained model.

# %%
# !python test.py --dataroot datasets/horse2zebra/testA --name horse2zebra_pretrained --model test --no_dropout

# %% [markdown]
# # Visualize

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/horse2zebra_pretrained/test_latest/images/n02381460_1010_fake.png')
plt.imshow(img)

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/horse2zebra_pretrained/test_latest/images/n02381460_1010_real.png')
plt.imshow(img)
